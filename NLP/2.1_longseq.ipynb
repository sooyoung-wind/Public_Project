# %% [markdown]
# ## 다음 문자열을 예측하는 RNN

# %%
import torch
import torch.optim as optim
import numpy as np

# %%
# Random seed to make results deterministic and reproducible
torch.manual_seed(0)

# %% [markdown]
# ### 학습 문장 생성

# %%
sentence = ("if you want to build a ship, don't drum up people together to "
            "collect wood and don't assign them tasks and work, but rather "
            "teach them to long for the endless immensity of the sea.")

# %% [markdown]
# * 이 프로젝트에서는 char(알파벳) 단위로 문자들을 생성합니다.

# %%
# make dictionary
char_set = list(set(sentence))
char_dic = {c: i for i, c in enumerate(char_set)}

# %%
# hyper parameters
dic_size = len(char_dic)
hidden_size = len(char_dic)
sequence_length = 10  # Any arbitrary number
learning_rate = 0.1

# %% [markdown]
# * 텍스트 생성을 위해서는 아래와 같은 데이터 구성을 제작해야합니다.

# %%
# data setting
x_data = []
y_data = []

for i in range(0, len(sentence) - sequence_length):
    x_str = sentence[i:i + sequence_length]
    y_str = sentence[i + 1: i + sequence_length + 1]
    print(i, x_str, '->', y_str)

    x_data.append([char_dic[c] for c in x_str])  # x str to index
    y_data.append([char_dic[c] for c in y_str])  # y str to index

x_one_hot = [np.eye(dic_size)[x] for x in x_data]
# Out:
# 0 if you wan -> f you want
# 1 f you want ->  you want
# 2  you want  -> you want t
# 3 you want t -> ou want to
# 4 ou want to -> u want to
# 5 u want to  ->  want to b
# 6  want to b -> want to bu
# 7 want to bu -> ant to bui
# 8 ant to bui -> nt to buil
# 9 nt to buil -> t to build
# 10 t to build ->  to build
# 11  to build  -> to build a
# 12 to build a -> o build a
# 13 o build a  ->  build a s
# 14  build a s -> build a sh
# 15 build a sh -> uild a shi
# 16 uild a shi -> ild a ship
# 17 ild a ship -> ld a ship,
# 18 ld a ship, -> d a ship,
# 19 d a ship,  ->  a ship, d
# 20  a ship, d -> a ship, do
# 21 a ship, do ->  ship, don
# 22  ship, don -> ship, don'
# 23 ship, don' -> hip, don't
# 24 hip, don't -> ip, don't
# 25 ip, don't  -> p, don't d
# 26 p, don't d -> , don't dr
# 27 , don't dr ->  don't dru
# 28  don't dru -> don't drum
# 29 don't drum -> on't drum
# 30 on't drum  -> n't drum u
# 31 n't drum u -> 't drum up
# 32 't drum up -> t drum up
# 33 t drum up  ->  drum up p
# 34  drum up p -> drum up pe
# 35 drum up pe -> rum up peo
# 36 rum up peo -> um up peop
# 37 um up peop -> m up peopl
# 38 m up peopl ->  up people
# 39  up people -> up people
# 40 up people  -> p people t
# 41 p people t ->  people to
# 42  people to -> people tog
# 43 people tog -> eople toge
# 44 eople toge -> ople toget
# 45 ople toget -> ple togeth
# 46 ple togeth -> le togethe
# 47 le togethe -> e together
# 48 e together ->  together
# 49  together  -> together t
# 50 together t -> ogether to
# 51 ogether to -> gether to
# 52 gether to  -> ether to c
# 53 ether to c -> ther to co
# 54 ther to co -> her to col
# 55 her to col -> er to coll
# 56 er to coll -> r to colle
# 57 r to colle ->  to collec
# 58  to collec -> to collect
# 59 to collect -> o collect
# 60 o collect  ->  collect w
# 61  collect w -> collect wo
# 62 collect wo -> ollect woo
# 63 ollect woo -> llect wood
# 64 llect wood -> lect wood
# 65 lect wood  -> ect wood a
# 66 ect wood a -> ct wood an
# 67 ct wood an -> t wood and
# 68 t wood and ->  wood and
# 69  wood and  -> wood and d
# 70 wood and d -> ood and do
# 71 ood and do -> od and don
# 72 od and don -> d and don'
# 73 d and don' ->  and don't
# 74  and don't -> and don't
# 75 and don't  -> nd don't a
# 76 nd don't a -> d don't as
# 77 d don't as ->  don't ass
# 78  don't ass -> don't assi
# 79 don't assi -> on't assig
# 80 on't assig -> n't assign
# 81 n't assign -> 't assign
# 82 't assign  -> t assign t
# 83 t assign t ->  assign th
# 84  assign th -> assign the
# 85 assign the -> ssign them
# 86 ssign them -> sign them
# 87 sign them  -> ign them t
# 88 ign them t -> gn them ta
# 89 gn them ta -> n them tas
# 90 n them tas ->  them task
# 91  them task -> them tasks
# 92 them tasks -> hem tasks
# 93 hem tasks  -> em tasks a
# 94 em tasks a -> m tasks an
# 95 m tasks an ->  tasks and
# 96  tasks and -> tasks and
# 97 tasks and  -> asks and w
# 98 asks and w -> sks and wo
# 99 sks and wo -> ks and wor
# 100 ks and wor -> s and work
# 101 s and work ->  and work,
# 102  and work, -> and work,
# 103 and work,  -> nd work, b
# 104 nd work, b -> d work, bu
# 105 d work, bu ->  work, but
# 106  work, but -> work, but
# 107 work, but  -> ork, but r
# 108 ork, but r -> rk, but ra
# 109 rk, but ra -> k, but rat
# 110 k, but rat -> , but rath
# 111 , but rath ->  but rathe
# 112  but rathe -> but rather
# 113 but rather -> ut rather
# 114 ut rather  -> t rather t
# 115 t rather t ->  rather te
# 116  rather te -> rather tea
# 117 rather tea -> ather teac
# 118 ather teac -> ther teach
# 119 ther teach -> her teach
# 120 her teach  -> er teach t
# 121 er teach t -> r teach th
# 122 r teach th ->  teach the
# 123  teach the -> teach them
# 124 teach them -> each them
# 125 each them  -> ach them t
# 126 ach them t -> ch them to
# 127 ch them to -> h them to
# 128 h them to  ->  them to l
# 129  them to l -> them to lo
# 130 them to lo -> hem to lon
# 131 hem to lon -> em to long
# 132 em to long -> m to long
# 133 m to long  ->  to long f
# 134  to long f -> to long fo
# 135 to long fo -> o long for
# 136 o long for ->  long for
# 137  long for  -> long for t
# 138 long for t -> ong for th
# 139 ong for th -> ng for the
# 140 ng for the -> g for the
# 141 g for the  ->  for the e
# 142  for the e -> for the en
# 143 for the en -> or the end
# 144 or the end -> r the endl
# 145 r the endl ->  the endle
# 146  the endle -> the endles
# 147 the endles -> he endless
# 148 he endless -> e endless
# 149 e endless  ->  endless i
# 150  endless i -> endless im
# 151 endless im -> ndless imm
# 152 ndless imm -> dless imme
# 153 dless imme -> less immen
# 154 less immen -> ess immens
# 155 ess immens -> ss immensi
# 156 ss immensi -> s immensit
# 157 s immensit ->  immensity
# 158  immensity -> immensity
# 159 immensity  -> mmensity o
# 160 mmensity o -> mensity of
# 161 mensity of -> ensity of
# 162 ensity of  -> nsity of t
# 163 nsity of t -> sity of th
# 164 sity of th -> ity of the
# 165 ity of the -> ty of the
# 166 ty of the  -> y of the s
# 167 y of the s ->  of the se
# 168  of the se -> of the sea
# 169 of the sea -> f the sea.

# %% [markdown]
# ### Data embedding
# * 전처리 된 데이터를 one hot 형태로 임베딩합니다.
# * 성능을 올리려면 embedding layer를 사용해도 좋습니다.

# %%
# transform as torch tensor variable
X = torch.FloatTensor(x_one_hot)
Y = torch.LongTensor(y_data)
# Out:
# <ipython-input-7-52579379b225>:2: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:261.)
#   X = torch.FloatTensor(x_one_hot)

# %%
# declare RNN + FC
class Net(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, layers):
        super(Net, self).__init__()
        self.rnn = torch.nn.RNN(input_dim, hidden_dim, num_layers=layers, batch_first=True)
        self.fc = torch.nn.Linear(hidden_dim, hidden_dim, bias=True)

    def forward(self, x):
        x, _status = self.rnn(x)
        x = self.fc(x)
        return x

# %%
# declare RNN + FC
class Net(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, layers):
        super(Net, self).__init__()
        self.rnn = torch.nn.RNN(input_dim, hidden_dim, num_layers=layers, batch_first=True)
        self.fc = torch.nn.Linear(hidden_dim, hidden_dim, bias=True)

    def forward(self, x):
        x, _status = self.rnn(x)
        x = self.fc(x)
        return x


net = Net(dic_size, hidden_size, 2)

# %% [markdown]
# ### 모델 학습 파트

# %%
# loss & optimizer setting
criterion = torch.nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), learning_rate)

# %%
# start training
for i in range(100):
    optimizer.zero_grad()
    outputs = net(X)
    loss = criterion(outputs.view(-1, dic_size), Y.view(-1))
    loss.backward()
    optimizer.step()

    results = outputs.argmax(dim=2)
    predict_str = "i" # 최초 문자열을 주워준 후 시작하면 더 정확한 예측이 가능합니다.
    for j, result in enumerate(results):
        # print(i, j, ''.join([char_set[t] for t in result]), loss.item())
        if j == 0:
            predict_str += ''.join([char_set[t] for t in result])
        else:
            predict_str += char_set[result[-1]]

    print(predict_str)
# Out:
# inffn,ffnf,nfnnfnfnfn,,f,f, ,fn,ffnfnn.ff,,f,f, ,f,,nnfnnfn,,nfnnnffnnfn,,nfnfn,n,ffnfnfffn,,nnff,,n fffnfn,,,.n,,nfnfnfnnfnf,fnnnfnf,f,,nfnnf,,,,.fnnff,,,,,fffnnfff nnf,,ffnnff,fn
# i
# ihndohcf tkfffpcffckffffffffkffdpcf cfff.fp.fdckfdc.dfffkcfd.cfcf.kfdp.fdp.ffpf.fipfdccffffccfdkffrkffffcffffnpfdccfffffkfffcffffffcffffdpfff.kfdkcffhpfddkfdpcfdpcfdhc.dcfdpfdp.fdc
# i   o tt  o t  t to ttoto t   o tt    t t  t o t  t ns t  oto t t     to o  ott   tt   tt   tot  t tt oso   o ts t nt o oso t tt ts    t ntot  t  tt t  o t  ttt  t  t  t  t  t    t
# i ntnec n n p n pn   hp n n ptp n n n p n ntpnnn n' nnnn n n  non n nntpnn n n nn n n n p n n np n n nn p p n n n o n n n p p nnnn n p n ntnn  non pn n p n n n nnl nnn npnnp np n n
# i   n n   n            n              n       n                          n       n      n           n                tn n      n          n  '               n                n
# i  io dt      e   l     lh      le t    eo    't 't  bon      bo le      '        le t   lhlo  l   e'e lo  m     lo  en  le    btelo l    bonlo     oe    e'e       neo     lh l
# io io dta a aoewoit  toelh   aodwe t  deto ioe lect  lo em toebo eect wo l dle aodwt taeeohce emeaoeco to eto bt toiee eeemoaoele toee doebo leao ltoeaeaeeoecee ee  eo it ithio   e
# it eeocta ttto co ttottt eeeoto ct toeeetoetmo lesteeetheteto co et e too tto  to lt ttett  toetetottt toeeto cthioe toeeer totetetoetetotco gtaoaetoettsetoretto eteethitocthemtstt
# it to ctao  to corotototoet oto ct to   to tho costhr ther tosco  tmo too tth  to cthtt tth toe  tos thto  torcthto  tor er toscththe  toscoscttor ths to  tr tth eth th to toe t  t
# io  o cth   torco ot tot s  oto ct th   to tho 'onth  t er th co  eso lo   th  to ct tr   h the  tos r th  tor thcos th  e  th  t th   thsconc tor th  to  trs th  r  th th the t
# it t  m h   to to  s t s e   to  t th   to t   lo th    er th to  em  wo   t   to 't tne  n t e  t s   t   ton o bos s   e  th  het e  to bo   dor the to    s tn     t  tn the s
# ithtordwa d donbomta todoe m don'thto m to th dlentorkoherdto bo lem  wo dla d ton'whtaedlnkther tost  tnemtorkohbor do  er to to tnem tonbonkodorktherdo  e d tn  n  th a  aoerdo l
# ithto dwa d donbo td d doe d don't tned do th  le th    ersto bo lem  wo dla d don't tae tn them todt  tne tor't bud doeher to lhetnem tonbo ' don'themsne e det   m etn tn a ems  t
# ithto dta d donboils t d e   do 't tned do t   le th  t em to bo le   to  la d don't tneitn them dod   tnd tor t bud d eher to lhetner tonbo 'tdor'themsne e det   mset  tn t ems  t
# itotou'ta d tonborld t doel  dod't tn d to tarnle to  t er tonbodle t tor la d don't tneitn ther tos   tns torkt bud t sher tonlh tner tonbonl dor'themso le d to  rdet  tn t emso l
# itosorkwa d tonburls t ther  don't tn   to a onle th  t er tonbodle t tornland don't tne tn ther tos   tns torko bus thsher tonlh ther tonbon' dor themsh le s tn  r  t  oh themsh c
# iposorkwa d toncuils t sher  don't tn   t  p onle thn ther tonbonle t tornland don't tns tn ther tosk  tns torko bus thsher tonch them thnconl dor themsh  e s tn     th on the sh c
# iposoukwand tonbuild t soer, don't unu  to p onlenton ther tonbonle t tornland don't unsetn them tosks tnd dork, bus t shem tonch them toncon' dor themsod e s tn   s th oh themsh c
# ipusoa wand to builu t sher, don't anum um a onle ton ther to bo le t wordland ton't ansian them toses tnd tork, bus t them tonch them to bon' doa themsmd e s tm  msith oh thems  i
# ipuaou wand to build t sher, don't anum um a ople to ethir to bo le t wood and ton't ansitn them tosks tnd tork, bui tather to ch them to bon' dor themsndle s t s nsith oh thems si
# ipuaou wand to luild d shep, don't anum up a ople to ethir to bo le t worn and don't ansipn them tosks tnd dork, bui tather to dh them to bon' dor the sndlens t   s ith of themshac
# ipmaoo  and to cuild d shep, don't dnum up a ople to ether to bo lect worn and don't dnsign them tosks tnd dork, but dather tonsh the  to bong dor the endle s t m ssiph oa the e st
# igmtou wand to build asshep, don't dnum up oeonle to ether to bo lect worc and don't dnsign them tosks and dork, but tother tonch them to bong dor the esdless tmm nsitn oa themskat
# ig aou wand to luild a ship, don't dnum up oeonle to ether to lo lect worc and don't dssign them tosks and aork, but tather tosch them to long for themessless imm nsigh of theme at
# ipuaou wand to build a ship, don't drum up oeonle to ether th bo lect worc and don't dssign them tosks and aork, but rother toach them to bong for the esdless irm nsith of theme at
# ipyaou wand tonbuild a ship, don't drum up peonle together th co lect wood and don't dssign them tosks and dork, buc rather toach them to cong for the e dless imm nsith of the e as
# ipyaou wand to cuild a ship, don't dnum up people to ether te co lect woon and don't dssign them tosks and aork, but rather teach them to cong for the esdless imm nsith of the e as
# ipyaoulwand to build a ship, don't drum up peonle together to lo lect wood and don't dssign them tosks and dork, but rather teach them to long for the crdless imm nsity of the chac
# ipyaou wand to build a ship, don't drum up people together to bo lect wood and don't dssign them tosks and aork, but rather toash the  to bong for the endless imm nsity of the eeas
# ipyaou wand to build a ship, don't drum up peonle together togbo lect wood and don't dssign them tasks and aork, but rather toach them tagbong for themerdless imm nsity of the cuac
# ipeaou want to luild a ship, don't drum up people together te lo lect wood and don't dssign them tasks and aork, but rather teach them ta long for the endless imm nsity of the e at
# ipuaou want ao build a ship, don't drum up people together to lo lect wood and don't dssign them tasks and aork, but rather teach them ta long for the endless imm nsity of the eeat
# ipuaoulwand tonbuild a ship, don't drum up people together ta collect wood and don't dssign them tasks and aork, but rather toach them ta long for the endless imm nsity of the eeac
# ipeaou wand to build a ship, don't drum up people together te collect wood and don't dssign them tasks and aork, but rather teach them ta long for the endless imm nsity of the eeac
# ipeaou want to build a ship, don't drum up people together te lollect wood and don't dssign them tasks and work, but rather teach them ta long for the endless immensity of the eeac
# ipeaou want to build a ship, don't arum up people together te collect wood and don't assign them tosks and work, but rather teach them to long for the endless immensity of the eeac
# ileaou want to build a ship, don't drum up people together te collect wood and don't dssign them tosks and work, but rather teach them to long for the endless immensity of the eeac
# ileaou want to build a ship, don't drum up people together to collect wood and don't dssign ther tasks and work, but rather toach them ta long for the sndless immensity of the s ac
# ileaou want to build a ship, don't drum up people together to collect wood and don't dssign them tasks and work, but rather toach them to long for the endless immensity of the eeac
# ileaou want to build a shig, don't arum up people together to collect wood and don't assign them tosks and work, but rather teach them to long for the endless immensity of the eeac
# ip aou want to build a ship, don't drum up people together to collect wood and don't dssign them tosks and work, but rather teach them to long for the endless immensity of the eeas
# ip aou want to build a ship, don't drum up people together to collect wood and don't dssign them tosks and work, but rather teach them to long for the endless immensity of the eeas
# ip aou want to build a ship, don't drum up people together to collect wood and don't dssign them tosks and work, but rather teach them to long for the endless immensity of the eeac
# ip aou want to build a ship, don't drum up people together to collect wood and don't dssign them tosks and work, but rather teach them to long for the endless immensity of the eeac
# ip aou want to build a ship, don't drum up people together to collect wood and don't dssign them tasks and work, but rather teach them ta long for the endless immensity of the eeac
# ip aou want to build a ship, don't arum up people together to collect wood and don't assign them tasks and work, but rather teach them ta long for the endless immensity of the eeas
# il aou want to build a ship, don't drum up people together to collect wood and don't dssign them tosks and work, but rather teach them to long for the endless immensity of the eeac
# il aou want to build a ship, don't drum up people together to collect wood and don't dssign them tosks and work, but rather teach them to long for the endless immensity of the eeac
# il aou want to build a ship, don't drum up people together to collect wood and don't dssign them tosks and work, but rather teach them to long for the endless immensity of the seac
# il aou want to build a ship, don't arum up people together to collect wood and don't assign them tasks and work, but rather teach them ta long for the endless immensity of the seac
# il aou want to build a ship, don't arum up people together to collect wood and don't assign them tosks and work, but rather teach them to long for the endless immensity of the eeac
# il aou want to build a ship, don't drum up people together to collect wood and don't dssign them tosks and work, but rather teach them to long for the endless immensity of the seac
# il aou want to build a ship, don't drum up people together to collect wood and don't dssign them tasks and work, but rather teach them ta long for the endless immensity of the seac
# ip aou want to build a ship, don't drum up people together to collect wood and don't dssign them tasks and work, but rather teach them ta long for the endless immensity of the seac
# ip aou want to build a ship, don't arum up people together to collect wood and don't assign them tasks and work, but rather teach them ta long for the endless immensity of the seac
# ip you want to build a ship, don't drum up people together to collect wood and don't dssign them tasks and work, but rather teach them ta long for the endless immensity of the seas
# ip you want to build a ship, don't drum up people together to collect wood and don't dssign them tasks and work, but rather teach them ta long for the endless immensity of the seas
# im you want to build a ship, don't arum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the seac
# im you want to build a ship, don't arum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the seac
# ig you want to build a ship, don't drum up people together to collect wood and don't dssign them tasks and work, but rather teach them to long for the endless immensity of the seac
# ig you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the seas
# ig you want to build a ship, don't arum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the seas
# ig you want to build a ship, don't drum up people together to collect wood and don't dssign them tasks and work, but rather teach them to long for the endless immensity of the seac
# ig you want to build a ship, don't drum up people together to collect wood and don't assign them tosks and work, but rather teach them to long for the endless immensity of the seac
# ig you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them ta long for the endless immensity of the seas
# it you want to build a ship, don't drum up people together to collect wood and don't dssign them tasks and work, but rather teach them ta long for the endless immensity of the seas
# it you want to build a ship, don't arum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the seac
# it you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea.
# it you want to build a ship, don't drum up people together to collect wood and don't dssign them tosks and work, but rather teach them to long for the endless immensity of the seas
# im you want to build a ship, don't arum up people together to collect wood and don't assign them tosks and work, but rather teach them to long for the endless immensity of the sea.
# if you want to build a ship, don't drum up people together to collect wood and don't assign them tosks and work, but rather teach them to long for the endless immensity of the sea.
# im you want to build a ship, don't arum up people together to collect wood and don't assign them thsks and work, but rather teach them ta long for themendless immensity of themseas
# it you want to build a shep, don't drum up people together to collect wood and don't dssign ther tasks and work, but rather teach the  ta long for toe endless immensity of the sens
# ip you want to build anship, don't drum up people together to bollect wood and don't dssign them tasks and dork, but rather teach them to bong for the endless immensity of the suac
# ip you want to build a ship, don't aoum up people together te collect wood and wod't assign them tasks and work, but rather toach them ta long for the endless immensity of the eeuc
# ip you want to cuild a ship, don't arum up people together toncollect wood and won't assign them tasks and work, but rather teach them to long for the endless immensity of the eeac
# ig you want to build a ship, don't drum up people together to collect wood and don't dssign them tosks and work, but rather toach them to long for the endless immensity of the sea.
# im you want to build a ship, don't arum up people together to collect wood and don't assign them tosks and dork, but rather teach them to long for the endless immensity of the seas
# il you want to build a ship, don't drum up people together to collect wood and don't dssign them tosks and work, but rather teach them to long for the endless immensity of the sea.
# il you want to build a ship, don't drum up people together to collect wood and don't dssign them tosks and work, but rather teach them to long for the endless immensity of the eea.
# ip you want to build a ship, don't arum up people together to collect wood and don't assign them tasks and work, but rather teach them ta long for the endless immensity of the seac
# ip you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them ta long for the endless immensity of the seac
# ip you want to build a ship, don't drum up people together to collect wood and don't dssign them tosks and work, but rather teach them to long for the endless immensity of the eeac
# il you want to build a ship, don't drum up people together to collect wood and don't assign them tosks and work, but rather teach them to long for the endless immensity of the seac
# im you want to build a ship, don't arum up people together to collect wood and don't assign them tosks and work, but rather teach them to long for the sndless immensity of the seac
# im you want to build a ship, don't drum up people together te collect wood and don't dssign them tasks and work, but rather teach them ta long for the endless immensity of the eeac
# if you want to build a ship, don't drum up people together te collect wood and don't dssign them tasks and work, but rather teach them ta long for the endless immensity of the seac
# if you want to build a ship, don't arum up people together te collect wood and don't assign them tasks and work, but rather teach them ta long for the endless immensity of the seac
# if you want to build a ship, don't drum up people together te collect wood and don't dssign them tasks and work, but rather teach them ta long for the endless immensity of the sea.
# if you want to build a ship, don't drum up people together te collect wood and don't dssign them tosks and work, but rather teach them ta long for the endless immensity of the sea.
# ig you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them ta long for the endless immensity of the sea.
# ig you want to build a ship, don't drum up people together to collect wood and don't dssign them tasks and work, but rather teach them ta long for the endless immensity of the sea.
# ig you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them ta long for the endless immensity of the sea.
# im you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them ta long for the endless immensity of the sea.
# ip you want to build a ship, don't drum up people together to collect wood and don't dssign them tasks and work, but rather teach them ta long for the endless immensity of the sea.
# if you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them ta long for the endless immensity of the sea.
# il you want to build a ship, don't drum up people together to collect wood and don't dssign them tasks and work, but rather teach them ta long for the endless immensity of the sea.
# il you want to build a ship, don't arum up people together to collect wood and don't assign them tasks and work, but rather teach them ta long for the endless immensity of the sea.
# ip you want to build a ship, don't drum up people together to collect wood and don't dssign them tosks and work, but rather teach them to long for the endless immensity of the sea.
