# %% [markdown]
# ## RNN 본격적인 학습

# %%
import torch
import torch.optim as optim
import numpy as np

# %%
# Random seed to make results deterministic and reproducible
torch.manual_seed(0)

# %% [markdown]
# ### 샘플데이터를 준비해봅시다.

# %%
sample = " if you want you"

# %% [markdown]
# * 주어진 데이터의 vocab 사전을 만듭니다.

# %%
# make dictionary
char_set = #TODO
char_dic = #TODO
print(char_dic)

# %% [markdown]
# ### 하이퍼 파라미터 설정

# %%
# hyper parameters
dic_size = #TODO
hidden_size = #TODO
learning_rate = 0.1

# %% [markdown]
# * 제작한 사전을 이용해서 알파벳들을 index로 변경해봅시다!

# %%
# data setting
sample_idx = [#TODO]
x_data = [#TODO]
x_one_hot = [np.eye(dic_size)[x] for x in x_data]
y_data = [#TODO]

# %% [markdown]
# * pytorch 학습을 위해 데이터의 타입을 torch로 변경해야합니다.

# %%
# transform as torch tensor variable
X = torch.FloatTensor(#TODO)
Y = torch.LongTensor(#TODO)

# %% [markdown]
# ### 모델 구성

# %%
# declare RNN
rnn = torch.nn.RNN(#TODO, #TODO, batch_first=True)

# %% [markdown]
# ### 모델 학습
# * 다음 텍스트를 예측하는 것은 '다중 분류' 입니다. 왜 일까요?

# %%
# loss & optimizer setting
criterion = #TODO
optimizer = #TODO

# %%
# start training
for i in range(50):
    optimizer.zero_grad()
    outputs, _status = rnn(X)
    loss = criterion(outputs.view(-1, dic_size), Y.view(-1))
    loss.backward()
    optimizer.step()

    result = outputs.data.numpy().argmax(axis=2)
    result_str = ''.join([char_set[c] for c in np.squeeze(result)])
    print(i, "loss: ", loss.item(), "prediction: ", result, "true Y: ", y_data, "prediction str: ", result_str)
