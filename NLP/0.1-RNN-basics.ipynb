# %% [markdown]
# ## Re: 0부터 시작하는 RNN

# %%
import torch
import numpy as np

# %%
# Random seed to make results deterministic and reproducible
torch.manual_seed(0)

# %% [markdown]
# ### RNN layer의 Hyperparameter
# * input_szie : RNN 레이어로 들어오는 입력 데이터의 특성(feature)의 수를 나타냅니다. 간단히 말해서, 각 시간 단계에서 입력 벡터의 크기를 의미합니다. 예를 들어, 단어를 임베딩하는 경우 임베딩 벡터의 크기가 input_size가 됩니다.
#
# * RNN 레이어의 숨겨진 상태(hidden state)의 크기를 정의합니다. 이는 RNN이 내부적으로 유지하는 메모리의 크기를 나타내며, 네트워크의 용량(capacity)과 복잡성(complexity)을 결정합니다. hidden_size는 각 시간 단계에서 RNN의 출력 벡터의 크기를 결정합니다.

# %%
# declare dimension
input_size = #
hidden_size = #

# %% [markdown]
# ### 데이터셋을 구성해봅시다.
# * one-hot vector를 이용해서 글자들을 벡터화 합니다.

# %%
# singleton example
# shape : (1, 1, 4)
# input_data_np = np.array([[[1, 0, 0, 0]]])

# sequential example
# shape : (3, 5, 4)
h = [1, 0, 0, 0]
e = [0, 1, 0, 0]
l = [0, 0, 1, 0]
o = [0, 0, 0, 1]
input_data_np = np.array([[h, e, l, l, o], [e, o, l, l, l], [l, l, e, e, l]], dtype=np.float32)

# %% [markdown]
# * 데이터의 shape을 알아봅시다.

# %%
input_data_np.shape
# Out:
# (3, 5, 4)

# %% [markdown]
# * Torch에서 사용하려면 변환이 필요합니다.

# %%
# transform as torch tensor
input_data = torch.Tensor(input_data_np)

# %% [markdown]
# ### 모델 구현

# %%
# declare RNN
rnn = torch.nn.RNN(#TODO, #TODO)

# %% [markdown]
# ### 모델 call
#
# * 모델 출력 결과를 확인해봅시다.

# %%
# check output
outputs, _status = rnn(#TODO)
print(outputs)
print(outputs.size())
# Out:
# tensor([[[-0.7497, -0.6135],
#          [-0.5282, -0.2473],
#          [-0.9136, -0.4269],
#          [-0.9136, -0.4269],
#          [-0.9028,  0.1180]],
#
#         [[-0.5753, -0.0070],
#          [-0.9052,  0.2597],
#          [-0.9173, -0.1989],
#          [-0.9173, -0.1989],
#          [-0.8996, -0.2725]],
#
#         [[-0.9077, -0.3205],
#          [-0.8944, -0.2902],
#          [-0.5134, -0.0288],
#          [-0.5134, -0.0288],
#          [-0.9127, -0.2222]]], grad_fn=<StackBackward0>)
# torch.Size([3, 5, 2])
